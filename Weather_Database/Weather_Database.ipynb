# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lats_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # if the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)    
# Print the city count to confirm sufficent count
len(cities)
# Out:
# 773

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=57fa3b89900262ba2836b3dad5e6a4ef

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for lat_lng, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (lat_lng % 50 == 0 and lat_lng >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_describe = city_weather['weather'][0]['description']
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_describe})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 1 | castro
# Processing Record 3 of Set 1 | mvomero
# Processing Record 4 of Set 1 | tasiilaq
# Processing Record 5 of Set 1 | rawannawi
# City not found. Skipping...
# Processing Record 6 of Set 1 | port alfred
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | belmopan
# Processing Record 9 of Set 1 | linhares
# Processing Record 10 of Set 1 | hermanus
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | clyde river
# Processing Record 13 of Set 1 | christchurch
# Processing Record 14 of Set 1 | namibe
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | saldanha
# Processing Record 17 of Set 1 | kaptanganj
# Processing Record 18 of Set 1 | basco
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | thompson
# Processing Record 21 of Set 1 | upernavik
# Processing Record 22 of Set 1 | avarua
# Processing Record 23 of Set 1 | bengkulu
# Processing Record 24 of Set 1 | hofn
# Processing Record 25 of Set 1 | wajima
# Processing Record 26 of Set 1 | hilo
# Processing Record 27 of Set 1 | awbari
# Processing Record 28 of Set 1 | lavrentiya
# Processing Record 29 of Set 1 | san carlos de bariloche
# Processing Record 30 of Set 1 | east london
# Processing Record 31 of Set 1 | nadym
# Processing Record 32 of Set 1 | sovetskiy
# Processing Record 33 of Set 1 | bluff
# Processing Record 34 of Set 1 | jardim
# Processing Record 35 of Set 1 | airai
# Processing Record 36 of Set 1 | mount isa
# Processing Record 37 of Set 1 | brae
# Processing Record 38 of Set 1 | faya
# Processing Record 39 of Set 1 | mataura
# Processing Record 40 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 1 | collierville
# Processing Record 42 of Set 1 | erzin
# Processing Record 43 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 1 | sao miguel
# Processing Record 45 of Set 1 | macusani
# Processing Record 46 of Set 1 | puerto ayora
# Processing Record 47 of Set 1 | smiltene
# Processing Record 48 of Set 1 | kodiak
# Processing Record 49 of Set 1 | ayer itam
# City not found. Skipping...
# Processing Record 50 of Set 1 | narsaq
# Processing Record 1 of Set 2 | hami
# Processing Record 2 of Set 2 | jamestown
# Processing Record 3 of Set 2 | san jose
# Processing Record 4 of Set 2 | cukai
# Processing Record 5 of Set 2 | marawi
# Processing Record 6 of Set 2 | sept-iles
# Processing Record 7 of Set 2 | fortuna
# Processing Record 8 of Set 2 | butaritari
# Processing Record 9 of Set 2 | bocaiuva
# Processing Record 10 of Set 2 | cabo san lucas
# Processing Record 11 of Set 2 | cheremushskiy
# Processing Record 12 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 2 | ushuaia
# Processing Record 14 of Set 2 | vao
# Processing Record 15 of Set 2 | cherskiy
# Processing Record 16 of Set 2 | port elizabeth
# Processing Record 17 of Set 2 | palimbang
# Processing Record 18 of Set 2 | kralendijk
# Processing Record 19 of Set 2 | sao jose da coroa grande
# Processing Record 20 of Set 2 | hithadhoo
# Processing Record 21 of Set 2 | bethel
# Processing Record 22 of Set 2 | qaanaaq
# Processing Record 23 of Set 2 | mayo
# Processing Record 24 of Set 2 | tilichiki
# Processing Record 25 of Set 2 | te anau
# Processing Record 26 of Set 2 | haines junction
# Processing Record 27 of Set 2 | saint-philippe
# Processing Record 28 of Set 2 | carinhanha
# Processing Record 29 of Set 2 | georgetown
# Processing Record 30 of Set 2 | barentu
# Processing Record 31 of Set 2 | carnarvon
# Processing Record 32 of Set 2 | mata
# Processing Record 33 of Set 2 | labutta
# City not found. Skipping...
# Processing Record 34 of Set 2 | san patricio
# Processing Record 35 of Set 2 | colac
# Processing Record 36 of Set 2 | port-gentil
# Processing Record 37 of Set 2 | longyearbyen
# Processing Record 38 of Set 2 | victor harbor
# Processing Record 39 of Set 2 | the pas
# Processing Record 40 of Set 2 | victoria
# Processing Record 41 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 2 | thiruvananthapuram
# Processing Record 43 of Set 2 | hohhot
# Processing Record 44 of Set 2 | chuy
# Processing Record 45 of Set 2 | saraland
# Processing Record 46 of Set 2 | nemuro
# Processing Record 47 of Set 2 | new norfolk
# Processing Record 48 of Set 2 | houma
# Processing Record 49 of Set 2 | ponta do sol
# Processing Record 50 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 3 | pemangkat
# Processing Record 2 of Set 3 | kavieng
# Processing Record 3 of Set 3 | kahului
# Processing Record 4 of Set 3 | miraflores
# Processing Record 5 of Set 3 | peniche
# Processing Record 6 of Set 3 | vila franca do campo
# Processing Record 7 of Set 3 | mar del plata
# Processing Record 8 of Set 3 | katsuura
# Processing Record 9 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 3 | deputatskiy
# Processing Record 11 of Set 3 | jaragua do sul
# Processing Record 12 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 3 | thano bula khan
# City not found. Skipping...
# Processing Record 14 of Set 3 | lacolle
# Processing Record 15 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 16 of Set 3 | kavaratti
# Processing Record 17 of Set 3 | mandalgovi
# Processing Record 18 of Set 3 | aripuana
# Processing Record 19 of Set 3 | ossora
# Processing Record 20 of Set 3 | alice springs
# Processing Record 21 of Set 3 | barao de melgaco
# Processing Record 22 of Set 3 | teguldet
# Processing Record 23 of Set 3 | laguna
# Processing Record 24 of Set 3 | fort dodge
# Processing Record 25 of Set 3 | offenburg
# Processing Record 26 of Set 3 | ngama
# Processing Record 27 of Set 3 | guangyuan
# Processing Record 28 of Set 3 | vaitape
# Processing Record 29 of Set 3 | cidreira
# Processing Record 30 of Set 3 | ribeira grande
# Processing Record 31 of Set 3 | tuatapere
# Processing Record 32 of Set 3 | virginia beach
# Processing Record 33 of Set 3 | bowen
# Processing Record 34 of Set 3 | mahebourg
# Processing Record 35 of Set 3 | hobart
# Processing Record 36 of Set 3 | albany
# Processing Record 37 of Set 3 | gejiu
# Processing Record 38 of Set 3 | itajobi
# Processing Record 39 of Set 3 | karatau
# Processing Record 40 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 3 | kandrian
# Processing Record 42 of Set 3 | arraial do cabo
# Processing Record 43 of Set 3 | lander
# Processing Record 44 of Set 3 | talakan
# Processing Record 45 of Set 3 | los llanos de aridane
# Processing Record 46 of Set 3 | barra do garcas
# Processing Record 47 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 48 of Set 3 | pangnirtung
# Processing Record 49 of Set 3 | ilulissat
# Processing Record 50 of Set 3 | litovko
# Processing Record 1 of Set 4 | cape town
# Processing Record 2 of Set 4 | faanui
# Processing Record 3 of Set 4 | santa cruz de la palma
# Processing Record 4 of Set 4 | along
# Processing Record 5 of Set 4 | aguimes
# Processing Record 6 of Set 4 | tarbagatay
# Processing Record 7 of Set 4 | magdagachi
# Processing Record 8 of Set 4 | cam pha
# City not found. Skipping...
# Processing Record 9 of Set 4 | talaya
# Processing Record 10 of Set 4 | dikson
# Processing Record 11 of Set 4 | lima
# Processing Record 12 of Set 4 | kasongo-lunda
# Processing Record 13 of Set 4 | mogzon
# Processing Record 14 of Set 4 | pisco
# Processing Record 15 of Set 4 | vangaindrano
# Processing Record 16 of Set 4 | karratha
# Processing Record 17 of Set 4 | senador jose porfirio
# Processing Record 18 of Set 4 | korcula
# Processing Record 19 of Set 4 | koslan
# Processing Record 20 of Set 4 | stoyba
# City not found. Skipping...
# Processing Record 21 of Set 4 | cap-aux-meules
# Processing Record 22 of Set 4 | bredasdorp
# Processing Record 23 of Set 4 | general roca
# Processing Record 24 of Set 4 | muravlenko
# Processing Record 25 of Set 4 | barrow
# Processing Record 26 of Set 4 | bandarbeyla
# Processing Record 27 of Set 4 | boyuibe
# Processing Record 28 of Set 4 | chokurdakh
# Processing Record 29 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 4 | tonantins
# Processing Record 31 of Set 4 | dolinsk
# Processing Record 32 of Set 4 | ixtapa
# Processing Record 33 of Set 4 | gizo
# Processing Record 34 of Set 4 | lodja
# Processing Record 35 of Set 4 | flagstaff
# Processing Record 36 of Set 4 | busselton
# Processing Record 37 of Set 4 | hasaki
# Processing Record 38 of Set 4 | ahuimanu
# Processing Record 39 of Set 4 | pontianak
# Processing Record 40 of Set 4 | hondo
# Processing Record 41 of Set 4 | olsztyn
# Processing Record 42 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 4 | alim
# Processing Record 44 of Set 4 | savalou
# Processing Record 45 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 4 | lalibela
# Processing Record 47 of Set 4 | abha
# Processing Record 48 of Set 4 | corinto
# Processing Record 49 of Set 4 | ilo
# Processing Record 50 of Set 4 | nikolskoye
# Processing Record 1 of Set 5 | adrar
# Processing Record 2 of Set 5 | souillac
# Processing Record 3 of Set 5 | kaitangata
# Processing Record 4 of Set 5 | margate
# Processing Record 5 of Set 5 | sioux lookout
# Processing Record 6 of Set 5 | esperance
# Processing Record 7 of Set 5 | villanueva
# Processing Record 8 of Set 5 | mvuma
# Processing Record 9 of Set 5 | solovetskiy
# City not found. Skipping...
# Processing Record 10 of Set 5 | poopo
# Processing Record 11 of Set 5 | mosetse
# Processing Record 12 of Set 5 | thunder bay
# Processing Record 13 of Set 5 | avera
# Processing Record 14 of Set 5 | yellowknife
# Processing Record 15 of Set 5 | wattegama
# Processing Record 16 of Set 5 | lata
# Processing Record 17 of Set 5 | rio gallegos
# Processing Record 18 of Set 5 | geraldton
# Processing Record 19 of Set 5 | grafton
# Processing Record 20 of Set 5 | vestmannaeyjar
# Processing Record 21 of Set 5 | yerofey pavlovich
# Processing Record 22 of Set 5 | ukiah
# Processing Record 23 of Set 5 | nuzvid
# Processing Record 24 of Set 5 | leningradskiy
# Processing Record 25 of Set 5 | kultuk
# Processing Record 26 of Set 5 | teguise
# Processing Record 27 of Set 5 | miandoab
# Processing Record 28 of Set 5 | saquarema
# Processing Record 29 of Set 5 | xining
# Processing Record 30 of Set 5 | patrocinio
# Processing Record 31 of Set 5 | salalah
# Processing Record 32 of Set 5 | beian
# Processing Record 33 of Set 5 | zhigansk
# Processing Record 34 of Set 5 | aspindza
# Processing Record 35 of Set 5 | bekhtery
# Processing Record 36 of Set 5 | urusha
# Processing Record 37 of Set 5 | bad salzungen
# Processing Record 38 of Set 5 | vostok
# Processing Record 39 of Set 5 | kapaa
# Processing Record 40 of Set 5 | byron bay
# Processing Record 41 of Set 5 | billings
# Processing Record 42 of Set 5 | maghama
# City not found. Skipping...
# Processing Record 43 of Set 5 | roald
# Processing Record 44 of Set 5 | tselinnoye
# Processing Record 45 of Set 5 | lebu
# Processing Record 46 of Set 5 | yenagoa
# Processing Record 47 of Set 5 | asau
# Processing Record 48 of Set 5 | torbay
# Processing Record 49 of Set 5 | vila
# Processing Record 50 of Set 5 | harwich
# Processing Record 1 of Set 6 | mount gambier
# Processing Record 2 of Set 6 | saint-joseph
# Processing Record 3 of Set 6 | dingle
# Processing Record 4 of Set 6 | richards bay
# Processing Record 5 of Set 6 | noumea
# Processing Record 6 of Set 6 | griffith
# Processing Record 7 of Set 6 | tual
# Processing Record 8 of Set 6 | madera
# Processing Record 9 of Set 6 | quthing
# Processing Record 10 of Set 6 | isangel
# Processing Record 11 of Set 6 | saskylakh
# Processing Record 12 of Set 6 | lulea
# Processing Record 13 of Set 6 | saint george
# Processing Record 14 of Set 6 | tombouctou
# Processing Record 15 of Set 6 | henties bay
# Processing Record 16 of Set 6 | aykhal
# Processing Record 17 of Set 6 | bambanglipuro
# Processing Record 18 of Set 6 | kitimat
# Processing Record 19 of Set 6 | pacific grove
# Processing Record 20 of Set 6 | marzuq
# Processing Record 21 of Set 6 | tres picos
# Processing Record 22 of Set 6 | bongandanga
# Processing Record 23 of Set 6 | klaksvik
# Processing Record 24 of Set 6 | ancud
# Processing Record 25 of Set 6 | shunyi
# Processing Record 26 of Set 6 | takoradi
# Processing Record 27 of Set 6 | sembe
# Processing Record 28 of Set 6 | sola
# Processing Record 29 of Set 6 | solsvik
# City not found. Skipping...
# Processing Record 30 of Set 6 | swan hill
# Processing Record 31 of Set 6 | gongzhuling
# Processing Record 32 of Set 6 | tommot
# Processing Record 33 of Set 6 | tarancon
# Processing Record 34 of Set 6 | severo-kurilsk
# Processing Record 35 of Set 6 | oktyabrskiy
# Processing Record 36 of Set 6 | chauk
# Processing Record 37 of Set 6 | provideniya
# Processing Record 38 of Set 6 | antsohihy
# Processing Record 39 of Set 6 | sokolo
# Processing Record 40 of Set 6 | itupiranga
# Processing Record 41 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 42 of Set 6 | tuktoyaktuk
# Processing Record 43 of Set 6 | port hedland
# Processing Record 44 of Set 6 | manado
# Processing Record 45 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 46 of Set 6 | bambous virieux
# Processing Record 47 of Set 6 | naze
# Processing Record 48 of Set 6 | alenquer
# Processing Record 49 of Set 6 | yarmouth
# Processing Record 50 of Set 6 | iqaluit
# Processing Record 1 of Set 7 | progreso
# Processing Record 2 of Set 7 | golub-dobrzyn
# Processing Record 3 of Set 7 | pevek
# Processing Record 4 of Set 7 | ulverstone
# Processing Record 5 of Set 7 | alanya
# Processing Record 6 of Set 7 | krasnoznamensk
# Processing Record 7 of Set 7 | ust-kuyga
# Processing Record 8 of Set 7 | athni
# Processing Record 9 of Set 7 | norman wells
# Processing Record 10 of Set 7 | la tuque
# Processing Record 11 of Set 7 | huilong
# Processing Record 12 of Set 7 | phalaborwa
# Processing Record 13 of Set 7 | nanortalik
# Processing Record 14 of Set 7 | dong xoai
# Processing Record 15 of Set 7 | candawaga
# City not found. Skipping...
# Processing Record 16 of Set 7 | zlitan
# Processing Record 17 of Set 7 | opuwo
# Processing Record 18 of Set 7 | koumac
# Processing Record 19 of Set 7 | namatanai
# Processing Record 20 of Set 7 | mjolby
# Processing Record 21 of Set 7 | la ronge
# Processing Record 22 of Set 7 | snasa
# Processing Record 23 of Set 7 | ponta delgada
# Processing Record 24 of Set 7 | sokoto
# Processing Record 25 of Set 7 | tabora
# Processing Record 26 of Set 7 | reggio di calabria
# Processing Record 27 of Set 7 | clyde
# Processing Record 28 of Set 7 | kainantu
# Processing Record 29 of Set 7 | srednekolymsk
# Processing Record 30 of Set 7 | waipawa
# Processing Record 31 of Set 7 | sindor
# Processing Record 32 of Set 7 | barcelona
# Processing Record 33 of Set 7 | dhemaji
# Processing Record 34 of Set 7 | bluefield
# Processing Record 35 of Set 7 | tiksi
# Processing Record 36 of Set 7 | toktogul
# Processing Record 37 of Set 7 | adeje
# Processing Record 38 of Set 7 | talnakh
# Processing Record 39 of Set 7 | antofagasta
# Processing Record 40 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 7 | derzhavinsk
# Processing Record 42 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 43 of Set 7 | lorengau
# Processing Record 44 of Set 7 | wewak
# Processing Record 45 of Set 7 | port blair
# Processing Record 46 of Set 7 | samur
# Processing Record 47 of Set 7 | kruisfontein
# Processing Record 48 of Set 7 | brokopondo
# Processing Record 49 of Set 7 | itacarambi
# Processing Record 50 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 8 | divnogorsk
# Processing Record 2 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 3 of Set 8 | yulara
# Processing Record 4 of Set 8 | steamboat springs
# Processing Record 5 of Set 8 | dicabisagan
# Processing Record 6 of Set 8 | itarema
# Processing Record 7 of Set 8 | terra nova
# Processing Record 8 of Set 8 | tolaga bay
# Processing Record 9 of Set 8 | serpa
# Processing Record 10 of Set 8 | tolbazy
# Processing Record 11 of Set 8 | ngunguru
# Processing Record 12 of Set 8 | camacha
# Processing Record 13 of Set 8 | bilibino
# Processing Record 14 of Set 8 | kununurra
# Processing Record 15 of Set 8 | cockburn town
# Processing Record 16 of Set 8 | ajka
# Processing Record 17 of Set 8 | saurimo
# Processing Record 18 of Set 8 | sitka
# Processing Record 19 of Set 8 | fort nelson
# Processing Record 20 of Set 8 | del carmen
# Processing Record 21 of Set 8 | falkenberg
# Processing Record 22 of Set 8 | caravelas
# Processing Record 23 of Set 8 | lompoc
# Processing Record 24 of Set 8 | argoncilhe
# Processing Record 25 of Set 8 | abancay
# Processing Record 26 of Set 8 | tura
# Processing Record 27 of Set 8 | svobodnyy
# Processing Record 28 of Set 8 | zurrieq
# Processing Record 29 of Set 8 | mayumba
# Processing Record 30 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 31 of Set 8 | flin flon
# Processing Record 32 of Set 8 | shebunino
# Processing Record 33 of Set 8 | tatawin
# Processing Record 34 of Set 8 | pyaozerskiy
# Processing Record 35 of Set 8 | flinders
# Processing Record 36 of Set 8 | pangkalanbuun
# Processing Record 37 of Set 8 | westport
# Processing Record 38 of Set 8 | den helder
# Processing Record 39 of Set 8 | puerto del rosario
# Processing Record 40 of Set 8 | jalu
# Processing Record 41 of Set 8 | kodinsk
# Processing Record 42 of Set 8 | tuban
# Processing Record 43 of Set 8 | manikpur
# Processing Record 44 of Set 8 | luderitz
# Processing Record 45 of Set 8 | khatanga
# Processing Record 46 of Set 8 | durazno
# Processing Record 47 of Set 8 | aklavik
# Processing Record 48 of Set 8 | nishihara
# Processing Record 49 of Set 8 | saint-denis
# Processing Record 50 of Set 8 | zhangye
# Processing Record 1 of Set 9 | ati
# Processing Record 2 of Set 9 | idar-oberstein
# Processing Record 3 of Set 9 | okha
# Processing Record 4 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 5 of Set 9 | monte carmelo
# Processing Record 6 of Set 9 | okhotsk
# Processing Record 7 of Set 9 | yura
# Processing Record 8 of Set 9 | san policarpo
# Processing Record 9 of Set 9 | de aar
# Processing Record 10 of Set 9 | severo-yeniseyskiy
# Processing Record 11 of Set 9 | waingapu
# Processing Record 12 of Set 9 | scarborough
# Processing Record 13 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 14 of Set 9 | roma
# Processing Record 15 of Set 9 | riyadh
# Processing Record 16 of Set 9 | codrington
# Processing Record 17 of Set 9 | broome
# Processing Record 18 of Set 9 | pocoes
# Processing Record 19 of Set 9 | masty
# Processing Record 20 of Set 9 | amapa
# Processing Record 21 of Set 9 | biritiba-mirim
# Processing Record 22 of Set 9 | zyryanovsk
# Processing Record 23 of Set 9 | pilao arcado
# City not found. Skipping...
# Processing Record 24 of Set 9 | coquimbo
# Processing Record 25 of Set 9 | saint-pierre
# Processing Record 26 of Set 9 | bonoua
# Processing Record 27 of Set 9 | kamina
# Processing Record 28 of Set 9 | puerto leguizamo
# Processing Record 29 of Set 9 | tessalit
# Processing Record 30 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 31 of Set 9 | piacabucu
# Processing Record 32 of Set 9 | vytegra
# Processing Record 33 of Set 9 | bom jardim
# Processing Record 34 of Set 9 | salaberry-de-valleyfield
# Processing Record 35 of Set 9 | afmadu
# City not found. Skipping...
# Processing Record 36 of Set 9 | kudat
# Processing Record 37 of Set 9 | painesville
# Processing Record 38 of Set 9 | kyaikto
# Processing Record 39 of Set 9 | tezu
# Processing Record 40 of Set 9 | sapao
# City not found. Skipping...
# Processing Record 41 of Set 9 | fier
# Processing Record 42 of Set 9 | skibbereen
# Processing Record 43 of Set 9 | mao
# Processing Record 44 of Set 9 | vanino
# Processing Record 45 of Set 9 | terrasini
# Processing Record 46 of Set 9 | yanchukan
# City not found. Skipping...
# Processing Record 47 of Set 9 | uttamapalaiyam
# Processing Record 48 of Set 9 | redcliffe
# Processing Record 49 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 9 | baturaja
# Processing Record 1 of Set 10 | verkhnevilyuysk
# Processing Record 2 of Set 10 | abu samrah
# Processing Record 3 of Set 10 | necochea
# Processing Record 4 of Set 10 | sobolevo
# Processing Record 5 of Set 10 | zyryanka
# Processing Record 6 of Set 10 | nome
# Processing Record 7 of Set 10 | lagoa
# Processing Record 8 of Set 10 | yumen
# Processing Record 9 of Set 10 | leshukonskoye
# Processing Record 10 of Set 10 | tomatlan
# Processing Record 11 of Set 10 | kitui
# Processing Record 12 of Set 10 | el cope
# Processing Record 13 of Set 10 | walvis bay
# Processing Record 14 of Set 10 | russell
# Processing Record 15 of Set 10 | kapoeta
# Processing Record 16 of Set 10 | bell ville
# Processing Record 17 of Set 10 | manokwari
# Processing Record 18 of Set 10 | moron de la frontera
# Processing Record 19 of Set 10 | samarai
# Processing Record 20 of Set 10 | furano
# Processing Record 21 of Set 10 | nizwa
# Processing Record 22 of Set 10 | sisimiut
# Processing Record 23 of Set 10 | ughelli
# Processing Record 24 of Set 10 | gimli
# Processing Record 25 of Set 10 | wazzan
# City not found. Skipping...
# Processing Record 26 of Set 10 | nastola
# Processing Record 27 of Set 10 | beringovskiy
# Processing Record 28 of Set 10 | tecoanapa
# Processing Record 29 of Set 10 | conde
# Processing Record 30 of Set 10 | pangody
# Processing Record 31 of Set 10 | chegdomyn
# Processing Record 32 of Set 10 | dwarka
# Processing Record 33 of Set 10 | cartagena
# Processing Record 34 of Set 10 | labuhan
# Processing Record 35 of Set 10 | tunceli
# Processing Record 36 of Set 10 | husavik
# Processing Record 37 of Set 10 | shalinskoye
# Processing Record 38 of Set 10 | san lorenzo
# Processing Record 39 of Set 10 | alpena
# Processing Record 40 of Set 10 | saint combs
# City not found. Skipping...
# Processing Record 41 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 42 of Set 10 | buala
# Processing Record 43 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 44 of Set 10 | rognan
# Processing Record 45 of Set 10 | angermunde
# Processing Record 46 of Set 10 | barhiya
# Processing Record 47 of Set 10 | paita
# Processing Record 48 of Set 10 | veraval
# Processing Record 49 of Set 10 | uzumlu
# City not found. Skipping...
# Processing Record 50 of Set 10 | kortkeros
# Processing Record 1 of Set 11 | constitucion
# Processing Record 2 of Set 11 | abrau-dyurso
# Processing Record 3 of Set 11 | paramonga
# Processing Record 4 of Set 11 | semey
# Processing Record 5 of Set 11 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 11 | maloshuyka
# City not found. Skipping...
# Processing Record 7 of Set 11 | san felipe
# Processing Record 8 of Set 11 | mahajanga
# Processing Record 9 of Set 11 | ucluelet
# Processing Record 10 of Set 11 | groton
# Processing Record 11 of Set 11 | luancheng
# Processing Record 12 of Set 11 | plouzane
# Processing Record 13 of Set 11 | filadelfia
# Processing Record 14 of Set 11 | duz
# City not found. Skipping...
# Processing Record 15 of Set 11 | lumsden
# Processing Record 16 of Set 11 | arivonimamo
# Processing Record 17 of Set 11 | atar
# Processing Record 18 of Set 11 | praya
# Processing Record 19 of Set 11 | san isidro
# Processing Record 20 of Set 11 | villamontes
# Processing Record 21 of Set 11 | plettenberg bay
# Processing Record 22 of Set 11 | kulob
# Processing Record 23 of Set 11 | lebedinyy
# Processing Record 24 of Set 11 | mariestad
# Processing Record 25 of Set 11 | xichang
# Processing Record 26 of Set 11 | berlevag
# Processing Record 27 of Set 11 | mnogovershinnyy
# Processing Record 28 of Set 11 | maragogi
# Processing Record 29 of Set 11 | yurimaguas
# Processing Record 30 of Set 11 | arman
# Processing Record 31 of Set 11 | mitsamiouli
# Processing Record 32 of Set 11 | san pedro
# Processing Record 33 of Set 11 | dezhou
# Processing Record 34 of Set 11 | lubango
# Processing Record 35 of Set 11 | shingu
# Processing Record 36 of Set 11 | newberry
# Processing Record 37 of Set 11 | papagaios
# Processing Record 38 of Set 11 | khandyga
# Processing Record 39 of Set 11 | anloga
# Processing Record 40 of Set 11 | neuquen
# Processing Record 41 of Set 11 | hobyo
# Processing Record 42 of Set 11 | lingao
# Processing Record 43 of Set 11 | najran
# Processing Record 44 of Set 11 | port hardy
# Processing Record 45 of Set 11 | olinda
# Processing Record 46 of Set 11 | vila velha
# Processing Record 47 of Set 11 | marystown
# Processing Record 48 of Set 11 | belyy yar
# Processing Record 49 of Set 11 | sokoni
# Processing Record 50 of Set 11 | iskateley
# Processing Record 1 of Set 12 | vajszlo
# Processing Record 2 of Set 12 | baneh
# Processing Record 3 of Set 12 | meiganga
# Processing Record 4 of Set 12 | sinnamary
# Processing Record 5 of Set 12 | gidole
# Processing Record 6 of Set 12 | sakakah
# Processing Record 7 of Set 12 | beyneu
# Processing Record 8 of Set 12 | half moon bay
# Processing Record 9 of Set 12 | nalut
# Processing Record 10 of Set 12 | komsomolskoye
# Processing Record 11 of Set 12 | karpathos
# Processing Record 12 of Set 12 | kelme
# Processing Record 13 of Set 12 | freeport
# Processing Record 14 of Set 12 | port keats
# Processing Record 15 of Set 12 | angoche
# Processing Record 16 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 17 of Set 12 | prince rupert
# Processing Record 18 of Set 12 | guerrero negro
# Processing Record 19 of Set 12 | dauriya
# Processing Record 20 of Set 12 | ashland
# Processing Record 21 of Set 12 | karaton
# Processing Record 22 of Set 12 | yerbogachen
# Processing Record 23 of Set 12 | chapais
# Processing Record 24 of Set 12 | am timan
# Processing Record 25 of Set 12 | batagay-alyta
# Processing Record 26 of Set 12 | mehamn
# Processing Record 27 of Set 12 | develi
# Processing Record 28 of Set 12 | kedrovyy
# Processing Record 29 of Set 12 | emerald
# Processing Record 30 of Set 12 | hangu
# Processing Record 31 of Set 12 | coahuayana
# Processing Record 32 of Set 12 | shihezi
# Processing Record 33 of Set 12 | matay
# Processing Record 34 of Set 12 | ahipara
# Processing Record 35 of Set 12 | bella union
# Processing Record 36 of Set 12 | mchinji
# Processing Record 37 of Set 12 | maldonado
# Processing Record 38 of Set 12 | calama
# Processing Record 39 of Set 12 | kaputa
# Processing Record 40 of Set 12 | hambantota
# Processing Record 41 of Set 12 | tupik
# Processing Record 42 of Set 12 | burley
# Processing Record 43 of Set 12 | sao filipe
# Processing Record 44 of Set 12 | yaan
# Processing Record 45 of Set 12 | torres vedras
# Processing Record 46 of Set 12 | alofi
# Processing Record 47 of Set 12 | port macquarie
# Processing Record 48 of Set 12 | iseyin
# Processing Record 49 of Set 12 | soto la marina
# Processing Record 50 of Set 12 | pucallpa
# Processing Record 1 of Set 13 | harper
# Processing Record 2 of Set 13 | bjornevatn
# Processing Record 3 of Set 13 | mirnyy
# Processing Record 4 of Set 13 | nacozari
# Processing Record 5 of Set 13 | springdale
# Processing Record 6 of Set 13 | calnali
# Processing Record 7 of Set 13 | olafsvik
# Processing Record 8 of Set 13 | rivadavia
# Processing Record 9 of Set 13 | izhma
# Processing Record 10 of Set 13 | paucartambo
# City not found. Skipping...
# Processing Record 11 of Set 13 | pitimbu
# Processing Record 12 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 13 of Set 13 | kudahuvadhoo
# Processing Record 14 of Set 13 | porto belo
# Processing Record 15 of Set 13 | arlit
# Processing Record 16 of Set 13 | usevya
# Processing Record 17 of Set 13 | marica
# Processing Record 18 of Set 13 | mayya
# Processing Record 19 of Set 13 | astana
# Processing Record 20 of Set 13 | raga
# Processing Record 21 of Set 13 | rio branco
# Processing Record 22 of Set 13 | qaqortoq
# Processing Record 23 of Set 13 | hamilton
# Processing Record 24 of Set 13 | new lenox
# Processing Record 25 of Set 13 | beaverlodge
# Processing Record 26 of Set 13 | bayburt
# Processing Record 27 of Set 13 | sabla
# Processing Record 28 of Set 13 | guia lopes da laguna
# Processing Record 29 of Set 13 | bonthe
# Processing Record 30 of Set 13 | mazamari
# Processing Record 31 of Set 13 | lithgow
# Processing Record 32 of Set 13 | broken hill
# Processing Record 33 of Set 13 | nyurba
# Processing Record 34 of Set 13 | aljezur
# Processing Record 35 of Set 13 | rocha
# Processing Record 36 of Set 13 | alyangula
# Processing Record 37 of Set 13 | benicarlo
# Processing Record 38 of Set 13 | port lincoln
# Processing Record 39 of Set 13 | lang son
# Processing Record 40 of Set 13 | borogontsy
# Processing Record 41 of Set 13 | sao miguel do oeste
# City not found. Skipping...
# Processing Record 42 of Set 13 | lazaro cardenas
# Processing Record 43 of Set 13 | amarante do maranhao
# Processing Record 44 of Set 13 | morant bay
# Processing Record 45 of Set 13 | falmouth
# Processing Record 46 of Set 13 | quatre cocos
# Processing Record 47 of Set 13 | carnduff
# Processing Record 48 of Set 13 | oranjemund
# Processing Record 49 of Set 13 | gallup
# Processing Record 50 of Set 13 | terrace
# Processing Record 1 of Set 14 | ambilobe
# Processing Record 2 of Set 14 | huarmey
# Processing Record 3 of Set 14 | baykit
# Processing Record 4 of Set 14 | pringsewu
# Processing Record 5 of Set 14 | khandbari
# Processing Record 6 of Set 14 | kenora
# Processing Record 7 of Set 14 | benjamin hill
# Processing Record 8 of Set 14 | salym
# Processing Record 9 of Set 14 | kimparana
# Processing Record 10 of Set 14 | veletma
# City not found. Skipping...
# Processing Record 11 of Set 14 | esfarayen
# Processing Record 12 of Set 14 | bontang
# Processing Record 13 of Set 14 | tarko-sale
# Processing Record 14 of Set 14 | gorontalo
# Processing Record 15 of Set 14 | uwayl
# City not found. Skipping...
# Processing Record 16 of Set 14 | vardo
# Processing Record 17 of Set 14 | tsienyane
# City not found. Skipping...
# Processing Record 18 of Set 14 | bosaso
# Processing Record 19 of Set 14 | dunedin
# Processing Record 20 of Set 14 | uribia
# Processing Record 21 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 22 of Set 14 | nuuk
# Processing Record 23 of Set 14 | halifax
# Processing Record 24 of Set 14 | kloulklubed
# Processing Record 25 of Set 14 | daru
# Processing Record 26 of Set 14 | urucurituba
# Processing Record 27 of Set 14 | porvoo
# Processing Record 28 of Set 14 | auki
# Processing Record 29 of Set 14 | juelsminde
# Processing Record 30 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 14 | saryozek
# Processing Record 32 of Set 14 | luau
# Processing Record 33 of Set 14 | charters towers
# Processing Record 34 of Set 14 | yining
# Processing Record 35 of Set 14 | port hawkesbury
# Processing Record 36 of Set 14 | sayyan
# Processing Record 37 of Set 14 | pangai
# Processing Record 38 of Set 14 | san-pedro
# Processing Record 39 of Set 14 | ostrovnoy
# Processing Record 40 of Set 14 | avanigadda
# Processing Record 41 of Set 14 | gamba
# Processing Record 42 of Set 14 | xalpatlahuac
# Processing Record 43 of Set 14 | cabedelo
# Processing Record 44 of Set 14 | egvekinot
# Processing Record 45 of Set 14 | kirakira
# Processing Record 46 of Set 14 | svetlaya
# Processing Record 47 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 48 of Set 14 | lamar
# Processing Record 49 of Set 14 | touros
# Processing Record 50 of Set 14 | ongandjera
# Processing Record 1 of Set 15 | fuyu
# Processing Record 2 of Set 15 | xacmaz
# Processing Record 3 of Set 15 | vanimo
# Processing Record 4 of Set 15 | ust-nera
# Processing Record 5 of Set 15 | saint-augustin
# Processing Record 6 of Set 15 | hudson bay
# Processing Record 7 of Set 15 | darhan
# Processing Record 8 of Set 15 | neaua
# Processing Record 9 of Set 15 | svetlogorsk
# Processing Record 10 of Set 15 | kamenka
# Processing Record 11 of Set 15 | diffa
# Processing Record 12 of Set 15 | ambala
# Processing Record 13 of Set 15 | orikhiv
# Processing Record 14 of Set 15 | sopot
# Processing Record 15 of Set 15 | bom jesus da lapa
# Processing Record 16 of Set 15 | ialibu
# Processing Record 17 of Set 15 | pointe-noire
# Processing Record 18 of Set 15 | alibag
# Processing Record 19 of Set 15 | hervey bay
# Processing Record 20 of Set 15 | payo
# Processing Record 21 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 22 of Set 15 | ust-uda
# Processing Record 23 of Set 15 | sinnai
# Processing Record 24 of Set 15 | gushikawa
# Processing Record 25 of Set 15 | turukhansk
# Processing Record 26 of Set 15 | kaeo
# Processing Record 27 of Set 15 | zhuhai
# Processing Record 28 of Set 15 | yunjinghong
# City not found. Skipping...
# Processing Record 29 of Set 15 | kuhdasht
# Processing Record 30 of Set 15 | alihe
# Processing Record 31 of Set 15 | kangaatsiaq
# Processing Record 32 of Set 15 | matara
# Processing Record 33 of Set 15 | pedernales
# Processing Record 34 of Set 15 | zykovo
# Processing Record 35 of Set 15 | ust-tsilma
# Processing Record 36 of Set 15 | taoudenni
# Processing Record 37 of Set 15 | boa esperanca
# Processing Record 38 of Set 15 | mahon
# Processing Record 39 of Set 15 | bafoussam
# Processing Record 40 of Set 15 | vilhena
# Processing Record 41 of Set 15 | hendek
# Processing Record 42 of Set 15 | waddan
# Processing Record 43 of Set 15 | koyelga
# Processing Record 44 of Set 15 | manzil tamim
# City not found. Skipping...
# Processing Record 45 of Set 15 | meulaboh
# Processing Record 46 of Set 15 | seoul
# Processing Record 47 of Set 15 | phayao
# Processing Record 48 of Set 15 | mackay
# Processing Record 49 of Set 15 | khani
# Processing Record 50 of Set 15 | goderich
# Processing Record 1 of Set 16 | mollendo
# Processing Record 2 of Set 16 | inhambane
# Processing Record 3 of Set 16 | tunduma
# Processing Record 4 of Set 16 | cumaribo
# City not found. Skipping...
# Processing Record 5 of Set 16 | san rafael
# Processing Record 6 of Set 16 | matamoros
# Processing Record 7 of Set 16 | campbell river
# Processing Record 8 of Set 16 | santa luzia
# Processing Record 9 of Set 16 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 16 | ngukurr
# City not found. Skipping...
# Processing Record 11 of Set 16 | tostamaa
# City not found. Skipping...
# Processing Record 12 of Set 16 | pagudpud
# Processing Record 13 of Set 16 | xiongshi
# City not found. Skipping...
# Processing Record 14 of Set 16 | makakilo city
# Processing Record 15 of Set 16 | mahaicony
# City not found. Skipping...
# Processing Record 16 of Set 16 | sao bras de alportel
# Processing Record 17 of Set 16 | heyang
# Processing Record 18 of Set 16 | sawakin
# Processing Record 19 of Set 16 | mahina
# Processing Record 20 of Set 16 | stawell
# Processing Record 21 of Set 16 | rungata
# City not found. Skipping...
# Processing Record 22 of Set 16 | hornepayne
# Processing Record 23 of Set 16 | balao
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 707

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Castro      BR -24.7911  -50.0119     62.78        93          88
# 1      Mvomero      TZ  -6.2500   38.6667     68.25        88           2
# 2     Tasiilaq      GL  65.6145  -37.6368     32.16        98         100
# 3  Port Alfred      ZA -33.5906   26.8910     67.17        85          95
# 4        Vaini      TO -21.2000 -175.2000     77.16        78          75
# 5     Belmopan      BZ  17.2500  -88.7667     93.58        74         100
# 6     Linhares      BR -19.3911  -40.0722     72.66        77           2
# 7     Hermanus      ZA -34.4187   19.2345     61.81        96         100
# 8      Rikitea      PF -23.1203 -134.9692     70.65        77          89
# 9  Clyde River      CA  70.4692  -68.5914     21.43        73          75
#
#    Wind Speed Current Description
# 0        3.06     overcast clouds
# 1        0.43           clear sky
# 2        2.10          light snow
# 3        1.99     overcast clouds
# 4       10.36       broken clouds
# 5        7.27     overcast clouds
# 6        6.62           clear sky
# 7        3.94     overcast clouds
# 8        8.77          light rain
# 9       10.36       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
